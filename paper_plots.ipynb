# %%
import seaborn as sns

from utils.plotting_utils_food101 import (
    food101_scaling_plots,
    food101_opt_n_l_plots,
    food101_opt_s_curve,
    food101_test_compression_plot,
    food101_alt_metric_scaling_plots,
    food101_naive_compression_plot,
)
from utils.plotting_utils_cityscapes import (
    cityscapes_scaling_plots,
    cityscapes_opt_n_l_plots,
    cityscapes_opt_s_curve,
    cityscapes_test_compression_plot,
    cityscapes_alt_metric_scaling_plots,
)
from utils.plotting_utils_isaid import (
    isaid_scaling_plots,
    isaid_opt_n_l_plots,
    isaid_opt_s_curve,
    isaid_test_compression_plot,
    isaid_alt_metric_scaling_plots,
)

sns.set_style("whitegrid")

# %% [markdown]
# ## Scaling

# %%
food101_scaling_plots()

# %%
cityscapes_scaling_plots()

# %%
isaid_scaling_plots()

# %% [markdown]
# ## Optimized $n$ and $L$

# %%
food101_opt_n_l_plots()

# %%
cityscapes_opt_n_l_plots()

# %%
isaid_opt_n_l_plots()

# %% [markdown]
# ## Storage-optimal

# %%
food101_opt_s_curve()

# %%
cityscapes_opt_s_curve()

# %%
isaid_opt_s_curve()

# %% [markdown]
# ## Naive Compression

# %%
food101_naive_compression_plot()

# %% [markdown]
# ## Test Compression

# %%
food101_test_compression_plot()

# %%
cityscapes_test_compression_plot()

# %%
isaid_test_compression_plot()

# %% [markdown]
# ## Alternative Metrics

# %%
food101_alt_metric_scaling_plots()

# %%
cityscapes_alt_metric_scaling_plots()

# %%
isaid_alt_metric_scaling_plots()
